# %% [markdown]
# ## Example: mean, standard deviation of a sample

# %%
# standard preamble
import numpy as np
import scipy as sp
from scipy import stats
from pylab import *
import matplotlib.pyplot as plt
# %matplotlib inline

# create a set of data and compute mean and variance
# This creates an array of 100 elements, gaussian-distributed with mean of 200 and RMS of 25
mu = 200
sigma = 25
x = mu + sigma*np.random.randn(500)
#print x[0:10]
n, bins, patches = hist(x, 50)


# various measures of "average value":
print ('Mean = {0:5.0f}'.format(sp.mean(x)))
print ('Median = {0:5.0f}'.format(sp.median(x)))
print ('Mode = {0:5.0f}'.format(0.5*(bins[argmax(n)]+bins[argmax(n)+1])))

# measure of the spreadx
print ('Standard deviation = {0:5.1f}'.format(np.std(x)))
# Out:
# Mean =   200
# Median =   200
# Mode =   200
# Standard deviation =  23.8

# %% [markdown]
# ### Different Distributions

# %%
# plot distribution normal
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(np.random.normal(10,20,size=10000),50,normed=True)
plt.show()

# %%
# plot distribution normal
plt.hist(np.random.uniform(5,10,size=10000),20,normed=True)
plt.show()

# %%
plt.hist(np.random.exponential(scale=2,size=10000),50,normed=True)
plt.show()

# %%
plt.hist(np.random.standard_cauchy(size=300),30,normed=True)
plt.show()

# %%
# plot distribution Triangular
plt.hist(np.random.triangular(5,10,15,size=1000000),50,normed=True)
plt.show()

# %%
# plot distribution Poisson
plt.hist(np.random.poisson(lam=4,size=50),100,normed=True)
plt.show()

# %%
# plot distribution Chi Square, DF=2
plt.hist(np.random.chisquare(2,size=10000),50,normed=True)
plt.show()

# %%
# plot distribution Chi Square, DF=4
plt.hist(np.random.chisquare(4,size=10000),50,normed=True)
plt.show()

# %%
# plot distribution Chi Square, DF=10
plt.hist(np.random.chisquare(10,size=10000),50,normed=True)
plt.show()

# %%
samp=np.random.uniform(10,20,size=10000)
counts,bin,ignore=plt.hist(samp,100)

# %% [markdown]
# ### Example: histogram fitting
#
# Here is an example of an unbinned fit of a set of events to a Gaussian PDF
# Courtesy http://glowingpython.blogspot.com/2012/07/distribution-fitting-with-scipy.html

# %%
from scipy.stats import norm
from numpy import linspace
from pylab import plot,show,hist,figure,title

# generate 100 events from a normal distrubution
# with mean 0 and standard deviation 1
sample = norm.rvs(loc=0,scale=1,size=100000) 

par = norm.fit(sample) # distribution fitting

#hist(sample,20)

print (par)

# now, par[0] and par[1] are the mean and 
# the standard deviation of the fitted distribution
x = linspace(-5,5,100)
# fitted distribution
pdf_fitted = norm.pdf(x,loc=par[0],scale=par[1])
# original distribution
pdf = norm.pdf(x)

title('Normal distribution')
plot(x,pdf_fitted,'r-',x,pdf,'b-')
hist(sample,10,normed=1,alpha=.8)
show()
# Out:
# (0.0008525470642021456, 0.99861007526889833)
